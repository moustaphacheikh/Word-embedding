# %% [markdown]
# # doc 2 vec

# %% [markdown]
# ### Import the necessary libraries

# %%
import os
import re
from nltk.tokenize import word_tokenize
from gensim.models.doc2vec import TaggedDocument
from gensim.models import Doc2Vec

# %% [markdown]
# ### Preprocessing methodes

# %%
def preprocessing(string):
    string =re.sub(r'[^\u0600-\u06FF]', ' ', string)  
    return re.sub(r"\s{2,}", " ", string).strip()

# %% [markdown]
# ### Helper class for momery

# %%
class LabeledLineSentence(object):
    def __init__(self, filename):
        self.filename = filename
    
    def __iter__(self):
        for uid, line in enumerate(open(self.filename,'r',encoding='utf8')):
            yield TaggedDocument(word_tokenize(line), ['SENTENCE_%s' % uid])

# %% [markdown]
# ### Create and train  doc2vec model

# %%
sentences = LabeledLineSentence('./corpus')
model = Doc2Vec(alpha=0.025, min_alpha=0.025,size=100,min_count=3,workers=4)  # use fixed learning rate
model.build_vocab(sentences)
for epoch in range(1):
    model.train(sentences,total_examples=model.corpus_count,epochs=epoch)
    model.alpha -= 0.002  # decrease the learning rate
    model.min_alpha = model.alpha  # fix the learning rate, no decay

# %% [markdown]
# ### Save and load the model

# %%
model_name='./saved_models/doc2vec_100size'
model.save(model_name)
doc2vec = Doc2Vec.load(model_name)

# %% [markdown]
# ## Using the trained model

# %% [markdown]
# ### Vocabulaire

# %%
doc2vec.wv.index2word
# Out:
# ['في',
#  'من',
#  '.',
#  "''",
#  'على',
#  'إلى',
#  ':',
#  '(',
#  ')',
#  'أن',
#  '``',
#  'التي',
#  '\\',
#  'عام',
#  'عن',
#  'أو',
#  '،',
#  ',',
#  'مع',
#  'كان',
#  'الذي',
#  'بين',
#  'هذه',
#  'ما',
#  'بعد',
#  'بن',
#  'حيث',
#  'هذا',
#  'كما',
#  'ذلك',
#  'هو',
#  'كانت',
#  'و',
#  'هي',
#  'لا',
#  'وقد',
#  'وفي',
#  'سنة',
#  'قبل',
#  'كل',
#  'حتى',
#  'مثل',
#  'بعض',
#  'قد',
#  'وهو',
#  'لم',
#  'خلال',
#  'ثم',
#  'وكان',
#  'وهي',
#  'عدد',
#  'تم',
#  'القرن',
#  'مدينة',
#  'المدينة',
#  'الله',
#  'أي',
#  'غير',
#  'أكثر',
#  '%',
#  'ومن',
#  'فيها',
#  'والتي',
#  'أنه',
#  '-',
#  'عبد',
#  'له',
#  'إلا',
#  'تلك',
#  'الدولة',
#  'بها',
#  'العالم',
#  'منها',
#  'عند',
#  'بشكل',
#  'العديد',
#  'فقد',
#  'محمد',
#  '{',
#  '}',
#  'ولكن',
#  '?',
#  'يمكن',
#  'id',
#  'https',
#  'text',
#  'url',
#  '//ar.wikipedia.org/wiki',
#  'title',
#  'عليه',
#  'أخرى',
#  'عشر',
#  'منذ',
#  'الحرب',
#  'المتحدة',
#  'الذين',
#  'أول',
#  'فإن',
#  'العربية',
#  'حوالي',
#  'هناك',
#  'مما',
#  'منطقة',
#  'تحت',
#  ']',
#  '[',
#  'لها',
#  'أكبر',
#  'البلاد',
#  'عندما',
#  'الأول',
#  'أحد',
#  'أما',
#  'فيه',
#  'ولا',
#  'يكون',
#  'وذلك',
#  'الثاني',
#  'ابن',
#  'جميع',
#  'عليها',
#  'علي',
#  'به',
#  'أيضا',
#  'اليوم',
#  'وكانت',
#  'أنها',
#  'قام',
#  'طريق',
#  'والذي',
#  'تكون',
#  'بسبب',
#  'الدين',
#  'الأولى',
#  'م',
#  'حول',
#  'العام',
#  'الحكومة',
#  'يتم',
#  'الملك',
#  'لكن',
#  'المنطقة',
#  'مصر',
#  'باسم',
#  'نحو',
#  'عدة',
#  'ذات',
#  'كبير',
#  'يوم',
#  'الجيش',
#  'اللغة',
#  'الولايات',
#  'الدول',
#  'الأرض',
#  'قال',
#  'اسم',
#  'السكان',
#  'بأن',
#  'كبيرة',
#  'مليون',
#  'الأخرى',
#  'ولم',
#  'البحر',
#  'حين',
#  'معظم',
#  'درجة',
#  'بما',
#  'بينما',
#  'الوقت',
#  'نظام',
#  'فترة',
#  'بالإضافة',
#  'المناطق',
#  'الفترة',
#  'مجموعة',
#  'ان',
#  'وبعد',
#  'فقط',
#  'سكان',
#  'وجود',
#  'ضد',
#  'فيما',
#  'آخر',
#  'عبر',
#  'دولة',
#  'جنوب',
#  'أبو',
#  'الرغم',
#  'وعلى',
#  'العالمية',
#  'إذا',
#  'دون',
#  'شمال',
#  'رئيس',
#  'إن',
#  'القوات',
#  'نسبة',
#  'أيضاً',
#  'الحكم',
#  'الكثير',
#  'الثانية',
#  'علم',
#  'أهم',
#  'نفس',
#  'واحدة',
#  'داخل',
#  'عهد',
#  'مجلس',
#  'خاصة',
#  'أثناء',
#  'ولاية',
#  'السلطان',
#  'ذلك،',
#  'النظام',
#  'وكذلك',
#  'الأمر',
#  'الناس',
#  'إذ',
#  'العمل',
#  'عملية',
#  'منهم',
#  'تقع',
#  'أصبحت',
#  'أبي',
#  'القديمة',
#  'بل',
#  'يوجد',
#  'الاتحاد',
#  'مرة',
#  'العربي',
#  'العرب',
#  'أوروبا',
#  'أصبح',
#  'ضمن',
#  'أحمد',
#  'نهر',
#  'المدن',
#  'وهذا',
#  'منه',
#  'تاريخ',
#  'واحد',
#  'استخدام',
#  'المسلمين',
#  'بناء',
#  'نهاية',
#  'حركة',
#  'عمر',
#  'وما',
#  'هـ',
#  'الشمال',
#  'حكم',
#  'مناطق',
#  'بداية',
#  'الغربية',
#  'حسب',
#  'الرئيس',
#  'سنوات',
#  'ثلاثة',
#  'شكل',
#  'إحدى',
#  'حالة',
#  'لهم',
#  'إليه',
#  'الثالث',
#  'إسرائيل',
#  'دول',
#  'الوطني',
#  'الشرق',
#  'الإسلام',
#  'الإنسان',
#  'لأن',
#  'الأراضي',
#  'الطاقة',
#  'نفسه',
#  'السنة',
#  'الخاصة',
#  'الشيخ',
#  'جامعة',
#  'شركة',
#  'بدأت',
#  'أهل',
#  'حرب',
#  'الإسلامية',
#  'الشمالية',
#  'الجزيرة',
#  'كانوا',
#  'العصر',
#  'ألف',
#  'شهر',
#  'جانب',
#  'كم',
#  'وقت',
#  'بلاد',
#  'أجل',
#  'كذلك',
#  'يكن',
#  'قامت',
#  'شبه',
#  'الأمريكية',
#  'ومع',
#  'المملكة',
#  'بدأ',
#  'الآن',
#  'تعتبر',
#  'أيضًا',
#  '10',
#  'الحياة',
#  'العراق',
#  'الشمس',
#  'العامة',
#  'ألمانيا',
#  'الغربي',
#  'بالنسبة',
#  '1',
#  'أعلى',
#  'نتيجة',
#  'فرنسا',
#  'الحرارة',
#  'الجنوب',
#  'الشرقية',
#  'شرق',
#  'التاسع',
#  'لكل',
#  'أنواع',
#  'السلطة',
#  'توجد',
#  'مساحة',
#  'مستوى',
#  'بني',
#  'عمل',
#  'السنوات',
#  'معركة',
#  'جديدة',
#  'جزيرة',
#  '3',
#  'فهي',
#  'أقل',
#  'مركز',
#  'عاصمة',
#  'فوق',
#  'وأن',
#  'الماء',
#  'ليس',
#  'أشهر',
#  'ثلاث',
#  'و\\',
#  'العسكرية',
#  'أدى',
#  'يد',
#  'كتاب',
#  'الوطنية',
#  'السياسية',
#  'عدم',
#  'الإمبراطورية',
#  'إليها',
#  'النبي',
#  'وضع',
#  'طول',
#  'مختلفة',
#  'التاريخ',
#  'العاصمة',
#  '–',
#  'أنحاء',
#  '20',
#  'مارس',
#  'الرئيسية',
#  'سبيل',
#  'وتم',
#  'سطح',
#  'الحديث',
#  'يناير',
#  'متر',
#  'الأكثر',
#  'أكتوبر',
#  '2',
#  'العلماء',
#  'العثمانية',
#  'لغة',
#  'نسمة',
#  'وسط',
#  'جمهورية',
#  'لدى',
#  '/',
#  'الحركة',
#  'فهو',
#  'هم',
#  'مجال',
#  'المياه',
#  'الأمم',
#  'مايو',
#  'أفريقيا',
#  'الجنوبية',
#  'عنه',
#  'محافظة',
#  '4',
#  'الجديدة',
#  'بذلك',
#  'منظمة',
#  'يعتبر',
#  '5',
#  'يقوم',
#  'حزب',
#  'سبتمبر',
#  'التعليم',
#  'لذلك',
#  'جزء',
#  'كتب',
#  'اليهود',
#  'كلمة',
#  'الحزب',
#  'الشعب',
#  'كثير',
#  'مملكة',
#  'شخص',
#  'يوليو',
#  'يونيو',
#  'البعض',
#  'وهناك',
#  'عبارة',
#  'فلسطين',
#  'إضافة',
#  'يعرف',
#  'الثورة',
#  'قوة',
#  'ديسمبر',
#  'الرابع',
#  'خارج',
#  'قوات',
#  'نوع',
#  'حد',
#  'يبلغ',
#  'الدولي',
#  'بقيادة',
#  'الإسلامي',
#  'بواسطة',
#  'الخليفة',
#  'حكومة',
#  '٪',
#  'نوفمبر',
#  '12',
#  'خط',
#  'الجزء',
#  'الكبير',
#  'تستخدم',
#  'أم',
#  'الاسم',
#  '15',
#  'غرب',
#  'العلم',
#  'بلغ',
#  'نصف',
#  'الغرب',
#  'لهذا',
#  'يجب',
#  'تقوم',
#  'وقال',
#  'ملك',
#  'لمدة',
#  'أمريكا',
#  'الأمير',
#  'وغيرها',
#  'صغيرة',
#  'الدولية',
#  'الفرنسية',
#  'أغسطس',
#  'عادة',
#  'الكنيسة',
#  'جديد',
#  'أواخر',
#  'وبين',
#  '30',
#  'المحيط',
#  'أيام',
#  'العهد',
#  'أمام',
#  '6',
#  'أعمال',
#  'المواد',
#  'الهند',
#  'الخامس',
#  'مختلف',
#  'الحدود',
#  'آل',
#  'أربعة',
#  'الاقتصادية',
#  'إنشاء',
#  'السادس',
#  'تسمى',
#  'الكبرى',
#  'الشرقي',
#  'دي',
#  'الميلاد',
#  'القرآن',
#  'وصل',
#  'وحتى',
#  'نظرية',
#  'بأنه',
#  'مدن',
#  'الضوء',
#  'نقل',
#  'المسيحية',
#  'قدم',
#  'العناصر',
#  'الجديد',
#  'الفلسطينية',
#  'وفاة',
#  'بحيث',
#  'فقال',
#  'جاء',
#  'عنها',
#  'هؤلاء',
#  'دمشق',
#  'الرئيسي',
#  'الكتاب',
#  'الأخيرة',
#  'يقول',
#  'الصين',
#  '8',
#  'يصل',
#  'لما',
#  'جبل',
#  'الإمام',
#  'المجتمع',
#  'رأس',
#  'أمر',
#  'باستخدام',
#  'أنَّ',
#  'حدود',
#  'المتوسط',
#  'المسجد',
#  'اليابان',
#  'ذكر',
#  'بريطانيا',
#  'الحديثة',
#  'المدارس',
#  'علماء',
#  'الميلادي',
#  'الأحمر',
#  'المصرية',
#  'فبراير',
#  '...',
#  '25',
#  'الوزراء',
#  'جبال',
#  'مكان',
#  'بيت',
#  'تعرف',
#  'العزيز',
#  'إنتاج',
#  'الدينية',
#  'المختلفة',
#  'إعادة',
#  'القدم',
#  'وهم',
#  'رغم',
#  'أبريل',
#  'معدل',
#  'الأسود',
#  'الأوروبي',
#  'البريطانية',
#  'جيش',
#  'الأوروبية',
#  'يسمى',
#  'ظهرت',
#  'عليهم',
#  'الولاية',
#  'دراسة',
#  'صناعة',
#  'الوسطى',
#  'المجلس',
#  'تعد',
#  'الأبيض',
#  'فكان',
#  'ويمكن',
#  'أصل',
#  'القديم',
#  'البابا',
#  'الأكبر',
#  'السياسي',
#  'آسيا',
#  'يقع',
#  'لهذه',
#  'الأعمال',
#  'وهذه',
#  '7',
#  'وعندما',
#  'أعضاء',
#  'نقطة',
#  'الفرنسي',
#  'يعود',
#  'حياة',
#  'اللغات',
#  'دور',
#  'الثامن',
#  'البحرية',
#  'الجمهورية',
#  'تصل',
#  'القدس',
#  'الجزائر',
#  'زيادة',
#  'قائمة',
#  'التجارة',
#  'باشا',
#  'الشام',
#  'العشرين',
#  'دولار',
#  'السابع',
#  'أقدم',
#  'موقع',
#  'الأردن',
#  'أرض',
#  'السلام',
#  'وبالتالي',
#  'الخارجية',
#  'عديدة',
#  'سلسلة',
#  'حرارة',
#  '14',
#  'بهذا',
#  'أفضل',
#  'عشرة',
#  'الداخلية',
#  'ق.م',
#  'ذو',
#  'القانون',
#  'م،',
#  'الناتج',
#  'العليا',
#  'الطبيعية',
#  'الطريق',
#  'يستخدم',
#  'جعل',
#  'تأثير',
#  'بعضها',
#  'التجارية',
#  'عالية',
#  'منتصف',
#  'الطرق',
#  'القبائل',
#  'كثيرة',
#  'فإنه',
#  'يعد',
#  'تشكل',
#  'المادة',
#  'الموجودة',
#  'المدينة،',
#  'المغرب',
#  'الألمانية',
#  'الرومانية',
#  'المجموعة',
#  'نطاق',
#  'إبراهيم',
#  'وادي',
#  'بعدها',
#  'الآخر',
#  'سكانها',
#  'يزيد',
#  'بغداد',
#  '؛',
#  'الشعبية',
#  'المركز',
#  'ـ',
#  'تكن',
#  'المحلية',
#  'مدرسة',
#  'الأساسية',
#  'درجات',
#  'فتح',
#  '11',
#  'وبعض',
#  'أوائل',
#  'طويلة',
#  '18',
#  'السعودية',
#  'بعده',
#  'إيطاليا',
#  'ولكنه',
#  'كرة',
#  'الكبيرة',
#  'أنهم',
#  'نفسها',
#  'أغلب',
#  'سعيد',
#  'أهمية',
#  'ارتفاع',
#  'السيطرة',
#  'العصور',
#  '16',
#  'تبلغ',
#  'الإسرائيلي',
#  'سوريا',
#  'بكر',
#  'تعمل',
#  'مليار',
#  'العلوم',
#  'عالم',
#  'تشمل',
#  'الأخير',
#  'العالم،',
#  'إدارة',
#  'المعلومات',
#  'المسلمون',
#  'الكويت',
#  'البلدان',
#  'النفط',
#  'وليس',
#  'السابق',
#  'عصر',
#  'طاقة',
#  'التاريخية',
#  'بأنها',
#  'قطاع',
#  'وخاصة',
#  'عرض',
#  'قانون',
#  'مرحلة',
#  'قصر',
#  'تزال',
#  'سواء',
#  'الرسمية',
#  'روسيا',
#  'تضم',
#  'الحيوانات',
#  'تطوير',
#  'البريطاني',
#  'المحلي',
#  'رقم',
#  'سرعة',
#  'بالقرب',
#  'المجال',
#  'آلاف',
#  'الشمالي',
#  'العملية',
#  'المعروف',
#  'ومنها',
#  'بـ',
#  'معه',
#  'المرحلة',
#  'لأنه',
#  'كتابه',
#  'أربع',
#  'الاقتصاد',
#  'ففي',
#  'العالمي',
#  '13',
#  '17',
#  'الإمبراطور',
#  'غزة',
#  'ظهور',
#  'جدا',
#  'أساس',
#  'هتلر',
#  '9',
#  'جهة',
#  'لكنه',
#  'الشهر',
#  'ابنه',
#  'قيادة',
#  'الدفاع',
#  'مباشرة',
#  'تعود',
#  'اليمن',
#  'القوة',
#  'حصل',
#  'بنسبة',
#  'أعلن',
#  'عين',
#  'ب',
#  'عشر،',
#  'قتل',
#  'شبكة',
#  'العلاقات',
#  'الجسم',
#  'معاهدة',
#  'يعمل',
#  'الاقتصادي',
#  'الثقافة',
#  'الواقعة',
#  'ثاني',
#  'يطلق',
#  'ليست',
#  'تمثل',
#  'عاد',
#  'خمسة',
#  'عقد',
#  'أجزاء',
#  'المدرسة',
#  'خاص',
#  'الحديد',
#  'شيء',
#  'المصري',
#  'الألماني',
#  'معينة',
#  'يعني',
#  'القاهرة',
#  'ميل',
#  'واسعة',
#  'وزارة',
#  '24',
#  'والده',
#  'قرية',
#  'الرحمن',
#  'الخاص',
#  'بي',
#  'السودان',
#  'مربع',
#  'موسى',
#  'بينها',
#  'طريقة',
#  'رسول',
#  'الإسرائيلية',
#  'ظل',
#  'ظهر',
#  'توفي',
#  'مدى',
#  'التقليدية',
#  'الأمن',
#  '2008',
#  'تحديد',
#  'تعني',
#  'كتلة',
#  'الحصول',
#  'طرق',
#  'وأصبح',
#  'تقدم',
#  'وقام',
#  'الخليج',
#  'الأمريكي',
#  'المعروفة',
#  'دار',
#  'يبقى',
#  'وسائل',
#  'فصل',
#  'التالية',
#  'هيئة',
#  'النوع',
#  'هما',
#  'عناصر',
#  'مقابل',
#  'الاستقلال',
#  'ثورة',
#  'وفقًا',
#  'عمليات',
#  'كامل',
#  'لديها',
#  'نشر',
#  'تأسيس',
#  'البرلمان',
#  'الدم',
#  'العلمية',
#  'سوى',
#  'الشكل',
#  'النجوم',
#  'تطور',
#  'تحتوي',
#  'العسكري',
#  'الاجتماعية',
#  'البلاد،',
#  '19',
#  'مشروع',
#  'كنيسة',
#  'قيام',
#  'الانتخابات',
#  'صاحب',
#  'وأصبحت',
#  'باللغة',
#  'النساء',
#  'الصغيرة',
#  'عرف',
#  'العدد',
#  '50',
#  'وحدة',
#  'الساحل',
#  'وتعتبر',
#  'الرومان',
#  'فكرة',
#  'الهيدروجين',
#  'حدث',
#  'سليمان',
#  'صلاح',
#  '21',
#  '2006',
#  'يؤدي',
#  '22',
#  'القوى',
#  'أخذ',
#  'نجد',
#  'مكة',
#  'الحالي',
#  'الاحتلال',
#  'حقوق',
#  'أنّ',
#  'خالد',
#  'ولد',
#  'حاليا',
#  'أراضي',
#  'برنامج',
#  'أبرز',
#  'أطلق',
#  'عامي',
#  'علاقة',
#  'قيمة',
#  'هنا',
#  'أخرى،',
#  'طلب',
#  'الجنوبي',
#  'تظهر',
#  'قبيلة',
#  'قرب',
#  'ستالين',
#  'الواقع',
#  'الكون',
#  'محاولة',
#  'حي',
#  'قبائل',
#  'لبنان',
#  'التالي',
#  'وإن',
#  'متوسط',
#  'فلا',
#  'تعتمد',
#  'انه',
#  'مصر،',
#  '2000',
#  'عثمان',
#  'الى',
#  '23',
#  'القمر',
#  'البحث',
#  'باب',
#  'مادة',
#  'عامة',
#  'الجامعة',
#  'دخل',
#  '100',
#  'تنظيم',
#  'وجه',
#  'الدستور',
#  'الوحيد',
#  '2007',
#  'دفع',
#  'حل',
#  'تحمل',
#  'كوريا',
#  'إسبانيا',
#  'الثالثة',
#  'روما',
#  'رفض',
#  'يزال',
#  'واسع',
#  'حياته',
#  'الآثار',
#  'مياه',
#  'فلم',
#  'بدون',
#  'استطاع',
#  'لقب',
#  'الكتب',
#  'عسكرية',
#  'يعتقد',
#  'خمس',
#  'ستة',
#  'لعام',
#  'اسمه',
#  'الحال',
#  'الموسيقى',
#  '>',
#  'بحر',
#  'رجال',
#  'الشعر',
#  'الزراعة',
#  'الغلاف',
#  'المسلحة',
#  'الملكية',
#  'نادي',
#  'أدت',
#  'جزر',
#  'باريس',
#  'ناحية',
#  'قناة',
#  'حجم',
#  'مهمة',
#  'تتكون',
#  'الأمطار',
#  'شهدت',
#  'مقاطعة',
#  'محمود',
#  'سن',
#  'وصلت',
#  'المذهب',
#  'النظر',
#  'المرض',
#  'منصب',
#  'صورة',
#  '26',
#  'شعبية',
#  'الأحداث',
#  'يوسف',
#  'لكرة',
#  'الكهربائية',
#  ...]

# %% [markdown]
# ### vector['word']

# %%
doc2vec['عن']
# Out:
# array([ -4.12502497e-01,   3.68395686e-01,   1.67868507e+00,
#         -5.74793696e-01,   1.39466190e+00,   5.16284704e-02,
#          1.48593879e+00,  -1.23921171e-01,   1.69755971e+00,
#         -5.15772581e-01,   2.06128192e+00,  -1.29071975e+00,
#         -2.36665559e+00,   6.94677904e-02,  -3.38853478e+00,
#          1.55399489e+00,   1.11979648e-01,  -4.14534062e-01,
#          2.15662241e+00,   2.59183455e+00,  -1.15146291e+00,
#         -8.47915113e-02,  -1.25018167e+00,   1.00558758e+00,
#          1.70379126e+00,  -2.19445914e-01,   2.99535942e+00,
#          2.19213152e+00,   2.25588703e-03,   2.08282995e+00,
#          1.96908879e+00,   2.31282806e+00,   8.03955972e-01,
#         -2.57951832e+00,   4.87604767e-01,  -6.80266500e-01,
#         -3.43659371e-01,   3.51458740e+00,  -2.08168149e+00,
#          1.76150054e-01,   6.34385049e-01,  -1.32878709e+00,
#          2.05715275e+00,  -2.23404694e+00,  -3.45026493e-01,
#         -5.35473704e-01,  -1.17432344e+00,  -1.22598600e+00,
#          1.80901361e+00,  -5.36611140e-01,  -1.01637101e+00,
#          2.15696359e+00,   9.31305289e-01,  -2.06210947e+00,
#          1.84635246e+00,  -2.12588251e-01,   6.04913056e-01,
#         -3.65159333e-01,   2.26691079e+00,   9.30260956e-01,
#         -2.01718974e+00,  -3.06572229e-01,   2.37158850e-01,
#         -8.68100464e-01,  -8.06589484e-01,   1.32288277e+00,
#         -2.56225586e+00,  -1.96920156e+00,   2.51284033e-01,
#          4.61794771e-02,  -1.79972172e+00,   1.72839493e-01,
#          2.06256509e+00,   1.27893102e+00,   3.69251370e-02,
#          2.28045419e-01,   1.06447268e+00,   6.33014739e-01,
#         -3.43731552e-01,  -2.30518505e-01,  -6.77036643e-01,
#         -2.84140676e-01,  -1.69701862e+00,   1.59991419e+00,
#         -2.11767888e+00,  -5.86012185e-01,   1.38841069e+00,
#          1.00320637e+00,  -3.19353282e-01,   3.14907193e+00,
#          8.45241770e-02,  -2.73594201e-01,  -5.35920441e-01,
#         -1.42244303e+00,  -7.23969758e-01,  -1.46588099e+00,
#          2.17245787e-01,  -1.82624006e+00,  -2.04819635e-01,
#         -8.07785869e-01], dtype=float32)

# %% [markdown]
# ### Most similar

# %%
doc2vec.most_similar('عن')
# Out:
# [('الرجاء', 0.4910587668418884),
#  ('بِأن', 0.46369048953056335),
#  ('الحرير', 0.45781776309013367),
#  ('وعن', 0.45533618330955505),
#  ('وأداء', 0.4451550245285034),
#  ('الضخ', 0.4429900348186493),
#  ('مع', 0.4340316653251648),
#  ('1360', 0.43295371532440186),
#  ('وقاية', 0.42782193422317505),
#  ('التنظيمي', 0.42598944902420044)]

# %%
# Out:
# 0.62628028564220639

# %%
doc2vec.most_similar(positive=['ذلك', 'لها'], negative=['يكفي'])
# Out:
# [('يسخن', 0.6317192316055298),
#  ('نفس', 0.6219510436058044),
#  ('الحاضر', 0.564719021320343),
#  ('الجماع', 0.5531127452850342),
#  ('هذا', 0.5514556765556335),
#  ('وبالعكس', 0.5488296151161194),
#  ('الإنكليزية،', 0.5415741205215454),
#  ('لهذا', 0.5407602190971375),
#  ('قرأت', 0.5304369330406189),
#  ('بهذا', 0.5289793014526367)]

# %% [markdown]
# ### Similarity between two words

# %%
doc2vec.similarity('وقاية','مع')
# Out:
# 0.62628028564220639

# %% [markdown]
# ### doesnt_match

# %%
doc2vec.doesnt_match(['نفس', 'ذلك', 'ولادته', 'البداية'])
# Out:
# 'ذلك'

# %% [markdown]
# ### vector(sentence)

# %%
string = 'الانتخابات الرئاسية الفرنسية'
sentence = word_tokenize(string)

# %%
doc2vec.infer_vector(sentence)

# %%
doc2vec.model.docvecs['SENTENCE_1']
